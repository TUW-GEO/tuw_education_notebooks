# %%
import xarray as xr

from pathlib import Path

RESOURCES = Path("data/SSM-CD-SIG40-R-DVEG_2018.zarr/")
xr.open_zarr(RESOURCES).resample(time="QS-DEC").mean().isel(time=3).band_data
# Out:
# <xarray.DataArray 'band_data' (y: 1200, x: 1200)> Size: 12MB
# array([[33.25641026, 44.03846154, 54.03846154, ..., 37.34210526,
#                 nan,         nan],
#        [29.87179487, 40.65384615, 47.71794872, ...,         nan,
#                 nan,         nan],
#        [30.3974359 , 41.93589744, 47.55128205, ...,         nan,
#                 nan,         nan],
#        ...,
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan]])
# Coordinates:
#   * x        (x) float64 10kB 4.8e+06 4.801e+06 4.801e+06 ... 5.399e+06 5.4e+06
#   * y        (y) float64 10kB 1.8e+06 1.799e+06 1.799e+06 ... 1.201e+06 1.2e+06
#     time     datetime64[ns] 8B 2018-09-01
# Attributes: (12/22)
#     AREA_OR_POINT:                Area
# ...
